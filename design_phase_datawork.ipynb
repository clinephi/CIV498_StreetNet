# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
importpath = "/content/drive/MyDrive/4.0_Fourth_Year/CIV498/VisionZero/!Resources/Data/latest-counts-by-location.csv"

# %%
df = pd.read_csv( importpath )

# %%
exportpath = "/content/drive/MyDrive/4.0_Fourth_Year/CIV498/VisionZero/Google Colab/Design_Phase/outputs/latest-counts-by-location-cleaned.csv"
df.to_csv(  exportpath )

# %% [markdown]
# # Import 2020 - 2029 data and check if weston in here.

# %%
importpath = "/content/drive/MyDrive/4.0_Fourth_Year/CIV498/VisionZero/!Resources/Data/latest-counts-by-location.csv"
exportpath = "/content/drive/MyDrive/4.0_Fourth_Year/CIV498/VisionZero/Google Colab/Design_Phase/outputs/latest-counts-by-location-cleaned.csv"

df = pd.read_csv( importpath ) 
df.to_csv(  exportpath )
